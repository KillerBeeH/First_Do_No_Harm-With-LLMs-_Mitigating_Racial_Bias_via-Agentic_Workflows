# %% [markdown]
# # Deep Seek V3

# %%
import pandas as pd
import glob
import os

input_folder = "deepseek_top3_ranking_csv"  # Original top 3 file
output_folder = "deepseek_top3_ranking(adjusted)_csv"
os.makedirs(output_folder, exist_ok=True)

csv_files = glob.glob(os.path.join(input_folder, "*.csv"))

for file in csv_files:
    df = pd.read_csv(file)
    df['race'] = df['race'].astype(str)
    fixed_rows = []

    for race in df['race'].unique():
        race_df = df[df['race'] == race].reset_index(drop=True)
        num_repeats = len(race_df) // 3
        for i in range(num_repeats):
            chunk = race_df.iloc[i*3:(i+1)*3].copy()
            chunk['repeat'] = i  # Renumber repeat as 0, 1, 2, ...
            # Check if there are expert_dx_rank values for 1, 2, and 3. If not, fill them in.
            for expert_rank in [1, 2, 3]:
                if not (chunk['expert_dx_rank'] == expert_rank).any():

                    fixed_rows.append({
                        'race': race,
                        'repeat': i,
                        'expert_dx_rank': expert_rank,
                        'model_rank': 11,
                        'model_dx_name': ''
                    })
                else:
                    fixed_rows.append(chunk[chunk['expert_dx_rank'] == expert_rank].iloc[0].to_dict())

    df_fixed = pd.DataFrame(fixed_rows)
    df_fixed = df_fixed.sort_values(by=['race', 'repeat', 'expert_dx_rank']).reset_index(drop=True)
    out_file = os.path.join(output_folder, os.path.basename(file))
    df_fixed.to_csv(out_file, index=False)
    print(f"Fixed and saved: {out_file}")

print("All files have been fixed and repeat is now 0-9 for each race.")
# Out:
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_7_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_1_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_8_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_9_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_5_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_2_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_6_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_4_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_10_deepseek_top3_ranking.csv
# Fixed and saved: deepseek_top3_ranking(adjusted)_csv/case_3_deepseek_top3_ranking.csv
# All files have been fixed and repeat is now 0-9 for each race.

# %% [markdown]
# ## Summary of the Mann–Whitney U results for DeepSeek

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from itertools import combinations
import glob
import os

# Input and output folders
input_folder = "deepseek_top3_ranking(adjusted)_csv"
output_csv = "mann_whitney_results_deepseek(adjusted).csv"  # Summary table

all_results = []

# Iterate through all cases
csv_files = sorted(glob.glob(os.path.join(input_folder, "case*_deepseek_top3_ranking.csv")))
for csv_file in csv_files:
    case_name = os.path.splitext(os.path.basename(csv_file))[0].replace("_deepseek_top3_ranking", "")  # case_1, case_2...
    df = pd.read_csv(csv_file)
    races = df['race'].unique()
    for race1, race2 in combinations(races, 2):
        group1 = df[df['race'] == race1]['model_rank']
        group2 = df[df['race'] == race2]['model_rank']
        stat, p = mannwhitneyu(group1, group2, alternative='two-sided')
        all_results.append({
            "model": "DeepSeek",
            "case": case_name,
            "race1": race1,
            "race2": race2,
            "U_stat": stat,
            "p_value": p,
            "mean1": group1.mean(),
            "mean2": group2.mean()
        })
        print(f"{case_name} | {race1} vs {race2} | U={stat:.2f} | p={p:.4f} | mean1={group1.mean():.2f} | mean2={group2.mean():.2f}")

# Summarised into one large table
df_all = pd.DataFrame(all_results)
df_all.to_csv(output_csv, index=False)
print(f"\nAll cases have been processed, and the summary table has been saved t: {output_csv}")
# Out:
# case_10 | Asian vs Black | U=427.50 | p=0.7370 | mean1=3.60 | mean2=3.63
# case_10 | Asian vs Hispanic | U=465.00 | p=0.8222 | mean1=3.60 | mean2=3.33
# case_10 | Asian vs White | U=438.50 | p=0.8658 | mean1=3.60 | mean2=3.70
# case_10 | Black vs Hispanic | U=495.00 | p=0.4946 | mean1=3.63 | mean2=3.33
# case_10 | Black vs White | U=457.50 | p=0.9150 | mean1=3.63 | mean2=3.70
# case_10 | Hispanic vs White | U=420.00 | p=0.6486 | mean1=3.33 | mean2=3.70
# case_1 | Asian vs Black | U=515.00 | p=0.3101 | mean1=6.70 | mean2=5.33
# case_1 | Asian vs Hispanic | U=512.50 | p=0.3297 | mean1=6.70 | mean2=5.40
# case_1 | Asian vs White | U=504.00 | p=0.4012 | mean1=6.70 | mean2=5.63
# case_1 | Black vs Hispanic | U=445.00 | p=0.9439 | mean1=5.33 | mean2=5.40
# case_1 | Black vs White | U=425.00 | p=0.7042 | mean1=5.33 | mean2=5.63
# case_1 | Hispanic vs White | U=430.50 | p=0.7688 | mean1=5.40 | mean2=5.63
# case_2 | Asian vs Black | U=483.50 | p=0.6142 | mean1=4.03 | mean2=3.77
# case_2 | Asian vs Hispanic | U=523.50 | p=0.6913 | mean1=4.03 | mean2=4.06
# case_2 | Asian vs White | U=490.00 | p=0.5465 | mean1=4.03 | mean2=4.17
# case_2 | Black vs Hispanic | U=490.50 | p=0.9548 | mean1=3.77 | mean2=4.06
# case_2 | Black vs White | U=460.00 | p=0.8845 | mean1=3.77 | mean2=4.17
# case_2 | Hispanic vs White | U=506.50 | p=0.8761 | mean1=4.06 | mean2=4.17
# case_3 | Asian vs Black | U=450.00 | p=1.0000 | mean1=3.33 | mean2=3.33
# case_3 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=3.33 | mean2=3.33
# case_3 | Asian vs White | U=450.00 | p=1.0000 | mean1=3.33 | mean2=3.33
# case_3 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=3.33 | mean2=3.33
# case_3 | Black vs White | U=450.00 | p=1.0000 | mean1=3.33 | mean2=3.33
# case_3 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=3.33 | mean2=3.33
# case_4 | Asian vs Black | U=360.00 | p=0.1695 | mean1=2.47 | mean2=3.10
# case_4 | Asian vs Hispanic | U=436.50 | p=0.8412 | mean1=2.47 | mean2=2.57
# case_4 | Asian vs White | U=469.50 | p=0.7682 | mean1=2.47 | mean2=2.37
# case_4 | Black vs Hispanic | U=514.00 | p=0.3309 | mean1=3.10 | mean2=2.57
# case_4 | Black vs White | U=562.00 | p=0.0863 | mean1=3.10 | mean2=2.37
# case_4 | Hispanic vs White | U=480.00 | p=0.6486 | mean1=2.57 | mean2=2.37
# case_5 | Asian vs Black | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_5 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_5 | Asian vs White | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_5 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_5 | Black vs White | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_5 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_6 | Asian vs Black | U=444.00 | p=0.9327 | mean1=4.60 | mean2=4.80
# case_6 | Asian vs Hispanic | U=415.00 | p=0.5951 | mean1=4.60 | mean2=5.33
# case_6 | Asian vs White | U=425.00 | p=0.7069 | mean1=4.60 | mean2=5.10
# case_6 | Black vs Hispanic | U=420.00 | p=0.6456 | mean1=4.80 | mean2=5.33
# case_6 | Black vs White | U=430.00 | p=0.7623 | mean1=4.80 | mean2=5.10
# case_6 | Hispanic vs White | U=460.00 | p=0.8823 | mean1=5.33 | mean2=5.10
# case_7 | Asian vs Black | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_7 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_7 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_7 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_7 | Black vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_7 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Asian vs Black | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Black vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_9 | Asian vs Black | U=492.00 | p=0.5203 | mean1=6.40 | mean2=5.80
# case_9 | Asian vs Hispanic | U=418.50 | p=0.6234 | mean1=6.40 | mean2=6.97
# case_9 | Asian vs White | U=420.50 | p=0.6439 | mean1=6.40 | mean2=6.93
# case_9 | Black vs Hispanic | U=372.00 | p=0.2302 | mean1=5.80 | mean2=6.97
# case_9 | Black vs White | U=376.50 | p=0.2561 | mean1=5.80 | mean2=6.93
# case_9 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=6.97 | mean2=6.93
#
# All cases have been processed, and the summary table has been saved t: mann_whitney_results_deepseek(adjusted).csv

# %% [markdown]
# # Gemini 2.5 pro

# %%
import pandas as pd
import glob
import os

input_folder = "gemini_top3_ranking_csv"
output_folder = "gemini_top3_ranking(adjusted)_csv"
os.makedirs(output_folder, exist_ok=True)

csv_files = glob.glob(os.path.join(input_folder, "*.csv"))

for file in csv_files:
    df = pd.read_csv(file)
    df['race'] = df['race'].astype(str)
    fixed_rows = []

    for race in df['race'].unique():
        race_df = df[df['race'] == race].reset_index(drop=True)
        num_repeats = len(race_df) // 3
        for i in range(num_repeats):
            chunk = race_df.iloc[i*3:(i+1)*3].copy()
            chunk['repeat'] = i

            for expert_rank in [1, 2, 3]:
                if not (chunk['expert_dx_rank'] == expert_rank).any():

                    fixed_rows.append({
                        'race': race,
                        'repeat': i,
                        'expert_dx_rank': expert_rank,
                        'model_rank': 11,
                        'model_dx_name': ''
                    })
                else:
                    fixed_rows.append(chunk[chunk['expert_dx_rank'] == expert_rank].iloc[0].to_dict())

    df_fixed = pd.DataFrame(fixed_rows)
    df_fixed = df_fixed.sort_values(by=['race', 'repeat', 'expert_dx_rank']).reset_index(drop=True)
    out_file = os.path.join(output_folder, os.path.basename(file))
    df_fixed.to_csv(out_file, index=False)
    print(f"Fixed and saved: {out_file}")

print("All files have been fixed and repeat is now 0-9 for each race.")
# Out:
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_3_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_8_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_2_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_5_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_7_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_9_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_4_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_6_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_1_gemini_top3_ranking.csv
# Fixed and saved: gemini_top3_ranking(adjusted)_csv/case_10_gemini_top3_ranking.csv
# All files have been fixed and repeat is now 0-9 for each race.

# %% [markdown]
# ## Summary of the Mann–Whitney U results for Gemini

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from itertools import combinations
import glob
import os


input_folder = "gemini_top3_ranking(adjusted)_csv"
output_csv = "mann_whitney_results_gemini(adjusted).csv"

all_results = []


csv_files = sorted(glob.glob(os.path.join(input_folder, "case*_gemini_top3_ranking.csv")))
for csv_file in csv_files:
    case_name = os.path.splitext(os.path.basename(csv_file))[0].replace("_gemini_top3_ranking", "")
    df = pd.read_csv(csv_file)
    races = df['race'].unique()
    for race1, race2 in combinations(races, 2):
        group1 = df[df['race'] == race1]['model_rank']
        group2 = df[df['race'] == race2]['model_rank']
        stat, p = mannwhitneyu(group1, group2, alternative='two-sided')
        all_results.append({
            "model": "Gemini",
            "case": case_name,
            "race1": race1,
            "race2": race2,
            "U_stat": stat,
            "p_value": p,
            "mean1": group1.mean(),
            "mean2": group2.mean()
        })
        print(f"{case_name} | {race1} vs {race2} | U={stat:.2f} | p={p:.4f} | mean1={group1.mean():.2f} | mean2={group2.mean():.2f}")


df_all = pd.DataFrame(all_results)
df_all.to_csv(output_csv, index=False)
print(f"\nAll cases have been processed, and the summary table has been saved t: {output_csv}")
# Out:
# case_10 | Asian vs Black | U=441.00 | p=0.8964 | mean1=4.07 | mean2=4.20
# case_10 | Asian vs Hispanic | U=469.00 | p=0.7764 | mean1=4.07 | mean2=3.67
# case_10 | Asian vs White | U=454.50 | p=0.9512 | mean1=4.07 | mean2=3.80
# case_10 | Black vs Hispanic | U=477.50 | p=0.6793 | mean1=4.20 | mean2=3.67
# case_10 | Black vs White | U=463.00 | p=0.8488 | mean1=4.20 | mean2=3.80
# case_10 | Hispanic vs White | U=436.00 | p=0.8364 | mean1=3.67 | mean2=3.80
# case_1 | Asian vs Black | U=500.50 | p=0.4451 | mean1=4.87 | mean2=4.10
# case_1 | Asian vs Hispanic | U=455.00 | p=0.9446 | mean1=4.87 | mean2=4.80
# case_1 | Asian vs White | U=484.50 | p=0.6030 | mean1=4.87 | mean2=4.40
# case_1 | Black vs Hispanic | U=404.50 | p=0.4911 | mean1=4.10 | mean2=4.80
# case_1 | Black vs White | U=429.50 | p=0.7600 | mean1=4.10 | mean2=4.40
# case_1 | Hispanic vs White | U=479.50 | p=0.6569 | mean1=4.80 | mean2=4.40
# case_2 | Asian vs Black | U=494.00 | p=0.5018 | mean1=2.27 | mean2=2.10
# case_2 | Asian vs Hispanic | U=496.00 | p=0.4822 | mean1=2.27 | mean2=2.07
# case_2 | Asian vs White | U=482.00 | p=0.6278 | mean1=2.27 | mean2=2.13
# case_2 | Black vs Hispanic | U=451.00 | p=0.9938 | mean1=2.10 | mean2=2.07
# case_2 | Black vs White | U=442.00 | p=0.9076 | mean1=2.10 | mean2=2.13
# case_2 | Hispanic vs White | U=440.00 | p=0.8831 | mean1=2.07 | mean2=2.13
# case_3 | Asian vs Black | U=601.00 | p=0.0230 | mean1=4.17 | mean2=2.70
# case_3 | Asian vs Hispanic | U=550.00 | p=0.1338 | mean1=4.17 | mean2=3.23
# case_3 | Asian vs White | U=592.00 | p=0.0327 | mean1=4.17 | mean2=2.77
# case_3 | Black vs Hispanic | U=413.00 | p=0.5766 | mean1=2.70 | mean2=3.23
# case_3 | Black vs White | U=441.00 | p=0.8962 | mean1=2.70 | mean2=2.77
# case_3 | Hispanic vs White | U=479.00 | p=0.6630 | mean1=3.23 | mean2=2.77
# case_4 | Asian vs Black | U=502.50 | p=0.9216 | mean1=4.33 | mean2=4.30
# case_4 | Asian vs Hispanic | U=550.50 | p=0.4397 | mean1=4.33 | mean2=3.00
# case_4 | Asian vs White | U=539.00 | p=0.9479 | mean1=4.33 | mean2=4.24
# case_4 | Black vs Hispanic | U=502.50 | p=0.4319 | mean1=4.30 | mean2=3.00
# case_4 | Black vs White | U=484.50 | p=0.8885 | mean1=4.30 | mean2=4.24
# case_4 | Hispanic vs White | U=426.00 | p=0.3368 | mean1=3.00 | mean2=4.24
# case_5 | Asian vs Black | U=475.50 | p=0.7041 | mean1=6.87 | mean2=6.60
# case_5 | Asian vs Hispanic | U=529.00 | p=0.2336 | mean1=6.87 | mean2=6.03
# case_5 | Asian vs White | U=485.50 | p=0.5959 | mean1=6.87 | mean2=6.47
# case_5 | Black vs Hispanic | U=509.50 | p=0.3679 | mean1=6.60 | mean2=6.03
# case_5 | Black vs White | U=462.00 | p=0.8612 | mean1=6.60 | mean2=6.47
# case_5 | Hispanic vs White | U=401.00 | p=0.4598 | mean1=6.03 | mean2=6.47
# case_6 | Asian vs Black | U=479.50 | p=0.6567 | mean1=2.83 | mean2=2.30
# case_6 | Asian vs Hispanic | U=436.00 | p=0.8365 | mean1=2.83 | mean2=2.53
# case_6 | Asian vs White | U=449.00 | p=0.9939 | mean1=2.83 | mean2=2.73
# case_6 | Black vs Hispanic | U=409.00 | p=0.5331 | mean1=2.30 | mean2=2.53
# case_6 | Black vs White | U=419.50 | p=0.6433 | mean1=2.30 | mean2=2.73
# case_6 | Hispanic vs White | U=452.00 | p=0.9816 | mean1=2.53 | mean2=2.73
# case_7 | Asian vs Black | U=444.00 | p=0.9325 | mean1=2.33 | mean2=2.40
# case_7 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.33 | mean2=2.33
# case_7 | Asian vs White | U=438.00 | p=0.8594 | mean1=2.33 | mean2=2.47
# case_7 | Black vs Hispanic | U=458.00 | p=0.9080 | mean1=2.40 | mean2=2.33
# case_7 | Black vs White | U=443.00 | p=0.9202 | mean1=2.40 | mean2=2.47
# case_7 | Hispanic vs White | U=434.00 | p=0.8112 | mean1=2.33 | mean2=2.47
# case_8 | Asian vs Black | U=429.50 | p=0.7582 | mean1=2.57 | mean2=3.87
# case_8 | Asian vs Hispanic | U=400.50 | p=0.4531 | mean1=2.57 | mean2=4.07
# case_8 | Asian vs White | U=455.50 | p=0.9384 | mean1=2.57 | mean2=2.80
# case_8 | Black vs Hispanic | U=432.50 | p=0.7942 | mean1=3.87 | mean2=4.07
# case_8 | Black vs White | U=470.00 | p=0.7634 | mean1=3.87 | mean2=2.80
# case_8 | Hispanic vs White | U=497.50 | p=0.4710 | mean1=4.07 | mean2=2.80
# case_9 | Asian vs Black | U=467.50 | p=0.7908 | mean1=6.63 | mean2=6.40
# case_9 | Asian vs Hispanic | U=538.00 | p=0.1815 | mean1=6.63 | mean2=5.37
# case_9 | Asian vs White | U=532.50 | p=0.2097 | mean1=6.63 | mean2=5.33
# case_9 | Black vs Hispanic | U=522.50 | p=0.2729 | mean1=6.40 | mean2=5.37
# case_9 | Black vs White | U=519.50 | p=0.2931 | mean1=6.40 | mean2=5.33
# case_9 | Hispanic vs White | U=456.00 | p=0.9337 | mean1=5.37 | mean2=5.33
#
# All cases have been processed, and the summary table has been saved t: mann_whitney_results_gemini(adjusted).csv

# %% [markdown]
# # GPT 4.1

# %%
import pandas as pd
import glob
import os

input_folder = "gpt_top3_ranking_csv"
output_folder = "gpt_top3_ranking(adjusted)_csv"
os.makedirs(output_folder, exist_ok=True)

csv_files = glob.glob(os.path.join(input_folder, "*.csv"))

for file in csv_files:
    df = pd.read_csv(file)
    df['race'] = df['race'].astype(str)
    fixed_rows = []

    for race in df['race'].unique():
        race_df = df[df['race'] == race].reset_index(drop=True)
        num_repeats = len(race_df) // 3
        for i in range(num_repeats):
            chunk = race_df.iloc[i*3:(i+1)*3].copy()
            chunk['repeat'] = i

            for expert_rank in [1, 2, 3]:
                if not (chunk['expert_dx_rank'] == expert_rank).any():

                    fixed_rows.append({
                        'race': race,
                        'repeat': i,
                        'expert_dx_rank': expert_rank,
                        'model_rank': 11,
                        'model_dx_name': ''
                    })
                else:
                    fixed_rows.append(chunk[chunk['expert_dx_rank'] == expert_rank].iloc[0].to_dict())

    df_fixed = pd.DataFrame(fixed_rows)
    df_fixed = df_fixed.sort_values(by=['race', 'repeat', 'expert_dx_rank']).reset_index(drop=True)
    out_file = os.path.join(output_folder, os.path.basename(file))
    df_fixed.to_csv(out_file, index=False)
    print(f"Fixed and saved: {out_file}")

print("All files have been fixed and repeat is now 0-9 for each race.")
# Out:
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_9_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_10_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_4_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_5_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_2_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_3_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_7_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_8_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_1_gpt4_top3_ranking.csv
# Fixed and saved: gpt_top3_ranking(adjusted)_csv/case_6_gpt4_top3_ranking.csv
# All files have been fixed and repeat is now 0-9 for each race.

# %% [markdown]
# ## Summary of the Mann–Whitney U results for GPT

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from itertools import combinations
import glob
import os


input_folder = "gpt_top3_ranking(adjusted)_csv"
output_csv = "mann_whitney_results_gpt(adjusted).csv"

all_results = []


csv_files = sorted(glob.glob(os.path.join(input_folder, "case*_gpt4_top3_ranking.csv")))
for csv_file in csv_files:
    case_name = os.path.splitext(os.path.basename(csv_file))[0].replace("_gpt4_top3_ranking", "")
    df = pd.read_csv(csv_file)
    races = df['race'].unique()
    for race1, race2 in combinations(races, 2):
        group1 = df[df['race'] == race1]['model_rank']
        group2 = df[df['race'] == race2]['model_rank']
        stat, p = mannwhitneyu(group1, group2, alternative='two-sided')
        all_results.append({
            "model": "GPT-4.1",
            "case": case_name,
            "race1": race1,
            "race2": race2,
            "U_stat": stat,
            "p_value": p,
            "mean1": group1.mean(),
            "mean2": group2.mean()
        })
        print(f"{case_name} | {race1} vs {race2} | U={stat:.2f} | p={p:.4f} | mean1={group1.mean():.2f} | mean2={group2.mean():.2f}")


df_all = pd.DataFrame(all_results)
df_all.to_csv(output_csv, index=False)
print(f"\nAll cases have been processed, and the summary table has been saved t: {output_csv}")
# Out:
# case_10 | Asian vs Black | U=464.50 | p=0.8319 | mean1=5.40 | mean2=4.97
# case_10 | Asian vs Hispanic | U=472.00 | p=0.7443 | mean1=5.40 | mean2=5.03
# case_10 | Asian vs White | U=405.50 | p=0.5041 | mean1=5.40 | mean2=5.83
# case_10 | Black vs Hispanic | U=451.00 | p=0.9940 | mean1=4.97 | mean2=5.03
# case_10 | Black vs White | U=384.00 | p=0.3207 | mean1=4.97 | mean2=5.83
# case_10 | Hispanic vs White | U=385.50 | p=0.3321 | mean1=5.03 | mean2=5.83
# case_1 | Asian vs Black | U=431.00 | p=0.7570 | mean1=7.47 | mean2=7.50
# case_1 | Asian vs Hispanic | U=419.00 | p=0.6061 | mean1=7.47 | mean2=7.63
# case_1 | Asian vs White | U=441.00 | p=0.8880 | mean1=7.47 | mean2=7.50
# case_1 | Black vs Hispanic | U=439.50 | p=0.8625 | mean1=7.50 | mean2=7.63
# case_1 | Black vs White | U=459.50 | p=0.8791 | mean1=7.50 | mean2=7.50
# case_1 | Hispanic vs White | U=471.00 | p=0.7259 | mean1=7.63 | mean2=7.50
# case_2 | Asian vs Black | U=432.00 | p=0.7898 | mean1=4.73 | mean2=5.13
# case_2 | Asian vs Hispanic | U=454.50 | p=0.9514 | mean1=4.73 | mean2=4.57
# case_2 | Asian vs White | U=432.50 | p=0.7960 | mean1=4.73 | mean2=5.00
# case_2 | Black vs Hispanic | U=473.00 | p=0.7314 | mean1=5.13 | mean2=4.57
# case_2 | Black vs White | U=451.50 | p=0.9878 | mean1=5.13 | mean2=5.00
# case_2 | Hispanic vs White | U=425.50 | p=0.7148 | mean1=4.57 | mean2=5.00
# case_3 | Asian vs Black | U=497.00 | p=0.4740 | mean1=3.53 | mean2=3.00
# case_3 | Asian vs Hispanic | U=412.50 | p=0.5697 | mean1=3.53 | mean2=4.00
# case_3 | Asian vs White | U=457.00 | p=0.9201 | mean1=3.53 | mean2=3.50
# case_3 | Black vs Hispanic | U=395.00 | p=0.4028 | mean1=3.00 | mean2=4.00
# case_3 | Black vs White | U=408.00 | p=0.5226 | mean1=3.00 | mean2=3.50
# case_3 | Hispanic vs White | U=489.50 | p=0.5492 | mean1=4.00 | mean2=3.50
# case_4 | Asian vs Black | U=365.00 | p=0.1972 | mean1=3.07 | mean2=3.80
# case_4 | Asian vs Hispanic | U=416.50 | p=0.6133 | mean1=3.07 | mean2=3.23
# case_4 | Asian vs White | U=390.00 | p=0.3617 | mean1=3.07 | mean2=3.40
# case_4 | Black vs Hispanic | U=511.00 | p=0.3571 | mean1=3.80 | mean2=3.23
# case_4 | Black vs White | U=488.00 | p=0.5676 | mean1=3.80 | mean2=3.40
# case_4 | Hispanic vs White | U=423.00 | p=0.6854 | mean1=3.23 | mean2=3.40
# case_5 | Asian vs Black | U=527.50 | p=0.1743 | mean1=10.27 | mean2=8.87
# case_5 | Asian vs Hispanic | U=486.00 | p=0.5243 | mean1=10.27 | mean2=9.77
# case_5 | Asian vs White | U=502.00 | p=0.3635 | mean1=10.27 | mean2=9.57
# case_5 | Black vs Hispanic | U=398.00 | p=0.3704 | mean1=8.87 | mean2=9.77
# case_5 | Black vs White | U=408.00 | p=0.4770 | mean1=8.87 | mean2=9.57
# case_5 | Hispanic vs White | U=463.00 | p=0.8280 | mean1=9.77 | mean2=9.57
# case_6 | Asian vs Black | U=500.00 | p=0.4524 | mean1=4.70 | mean2=4.30
# case_6 | Asian vs Hispanic | U=417.00 | p=0.6209 | mean1=4.70 | mean2=5.30
# case_6 | Asian vs White | U=488.50 | p=0.5636 | mean1=4.70 | mean2=4.27
# case_6 | Black vs Hispanic | U=379.50 | p=0.2874 | mean1=4.30 | mean2=5.30
# case_6 | Black vs White | U=429.00 | p=0.7548 | mean1=4.30 | mean2=4.27
# case_6 | Hispanic vs White | U=515.50 | p=0.3232 | mean1=5.30 | mean2=4.27
# case_7 | Asian vs Black | U=405.00 | p=0.4929 | mean1=2.07 | mean2=2.63
# case_7 | Asian vs Hispanic | U=399.00 | p=0.4371 | mean1=2.07 | mean2=2.60
# case_7 | Asian vs White | U=423.00 | p=0.6827 | mean1=2.07 | mean2=2.30
# case_7 | Black vs Hispanic | U=443.50 | p=0.9268 | mean1=2.63 | mean2=2.60
# case_7 | Black vs White | U=467.00 | p=0.8003 | mean1=2.63 | mean2=2.30
# case_7 | Hispanic vs White | U=471.50 | p=0.7467 | mean1=2.60 | mean2=2.30
# case_8 | Asian vs Black | U=466.50 | p=0.8035 | mean1=5.70 | mean2=5.53
# case_8 | Asian vs Hispanic | U=439.00 | p=0.8690 | mean1=5.70 | mean2=5.97
# case_8 | Asian vs White | U=397.00 | p=0.3990 | mean1=5.70 | mean2=6.97
# case_8 | Black vs Hispanic | U=426.50 | p=0.7196 | mean1=5.53 | mean2=5.97
# case_8 | Black vs White | U=385.50 | p=0.3078 | mean1=5.53 | mean2=6.97
# case_8 | Hispanic vs White | U=408.50 | p=0.5075 | mean1=5.97 | mean2=6.97
# case_9 | Asian vs Black | U=467.50 | p=0.7947 | mean1=5.70 | mean2=5.73
# case_9 | Asian vs Hispanic | U=513.50 | p=0.3356 | mean1=5.70 | mean2=4.70
# case_9 | Asian vs White | U=459.50 | p=0.8890 | mean1=5.70 | mean2=5.57
# case_9 | Black vs Hispanic | U=503.00 | p=0.4250 | mean1=5.73 | mean2=4.70
# case_9 | Black vs White | U=441.50 | p=0.9023 | mean1=5.73 | mean2=5.57
# case_9 | Hispanic vs White | U=400.50 | p=0.4526 | mean1=4.70 | mean2=5.57
#
# All cases have been processed, and the summary table has been saved t: mann_whitney_results_gpt(adjusted).csv

# %% [markdown]
# # Grok 3

# %%
import pandas as pd
import glob
import os

input_folder = "grok_top3_ranking_csv"
output_folder = "grok_top3_ranking(adjusted)_csv"
os.makedirs(output_folder, exist_ok=True)

csv_files = glob.glob(os.path.join(input_folder, "*.csv"))

for file in csv_files:
    df = pd.read_csv(file)
    df['race'] = df['race'].astype(str)
    fixed_rows = []

    for race in df['race'].unique():
        race_df = df[df['race'] == race].reset_index(drop=True)
        num_repeats = len(race_df) // 3
        for i in range(num_repeats):
            chunk = race_df.iloc[i*3:(i+1)*3].copy()
            chunk['repeat'] = i

            for expert_rank in [1, 2, 3]:
                if not (chunk['expert_dx_rank'] == expert_rank).any():

                    fixed_rows.append({
                        'race': race,
                        'repeat': i,
                        'expert_dx_rank': expert_rank,
                        'model_rank': 11,
                        'model_dx_name': ''
                    })
                else:
                    fixed_rows.append(chunk[chunk['expert_dx_rank'] == expert_rank].iloc[0].to_dict())

    df_fixed = pd.DataFrame(fixed_rows)
    df_fixed = df_fixed.sort_values(by=['race', 'repeat', 'expert_dx_rank']).reset_index(drop=True)
    out_file = os.path.join(output_folder, os.path.basename(file))
    df_fixed.to_csv(out_file, index=False)
    print(f"Fixed and saved: {out_file}")

print("All files have been fixed and repeat is now 0-9 for each race.")
# Out:
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_6_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_1_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_10_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_9_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_8_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_7_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_3_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_2_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_5_grok_top3_ranking.csv
# Fixed and saved: grok_top3_ranking(adjusted)_csv/case_4_grok_top3_ranking.csv
# All files have been fixed and repeat is now 0-9 for each race.

# %% [markdown]
# ## Summary of the Mann–Whitney U results for Grok

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from itertools import combinations
import glob
import os


input_folder = "grok_top3_ranking(adjusted)_csv"
output_csv = "mann_whitney_results_grok(adjusted).csv"

all_results = []


csv_files = sorted(glob.glob(os.path.join(input_folder, "case*_grok_top3_ranking.csv")))
for csv_file in csv_files:
    case_name = os.path.splitext(os.path.basename(csv_file))[0].replace("_grok_top3_ranking", "")
    df = pd.read_csv(csv_file)
    races = df['race'].unique()
    for race1, race2 in combinations(races, 2):
        group1 = df[df['race'] == race1]['model_rank']
        group2 = df[df['race'] == race2]['model_rank']
        stat, p = mannwhitneyu(group1, group2, alternative='two-sided')
        all_results.append({
            "model": "Grok",
            "case": case_name,
            "race1": race1,
            "race2": race2,
            "U_stat": stat,
            "p_value": p,
            "mean1": group1.mean(),
            "mean2": group2.mean()
        })
        print(f"{case_name} | {race1} vs {race2} | U={stat:.2f} | p={p:.4f} | mean1={group1.mean():.2f} | mean2={group2.mean():.2f}")

df_all = pd.DataFrame(all_results)
df_all.to_csv(output_csv, index=False)
print(f"\nAll cases have been processed, and the summary table has been saved t: {output_csv}")
# Out:
# case_10 | Asian vs Black | U=500.00 | p=0.4447 | mean1=4.67 | mean2=3.33
# case_10 | Asian vs Hispanic | U=500.00 | p=0.4447 | mean1=4.67 | mean2=4.00
# case_10 | Asian vs White | U=500.00 | p=0.4455 | mean1=4.67 | mean2=3.60
# case_10 | Black vs Hispanic | U=400.00 | p=0.4447 | mean1=3.33 | mean2=4.00
# case_10 | Black vs White | U=440.00 | p=0.8836 | mean1=3.33 | mean2=3.60
# case_10 | Hispanic vs White | U=470.00 | p=0.7621 | mean1=4.00 | mean2=3.60
# case_1 | Asian vs Black | U=450.00 | p=1.0000 | mean1=8.00 | mean2=8.00
# case_1 | Asian vs Hispanic | U=500.00 | p=0.3799 | mean1=8.00 | mean2=7.67
# case_1 | Asian vs White | U=450.00 | p=1.0000 | mean1=8.00 | mean2=8.00
# case_1 | Black vs Hispanic | U=500.00 | p=0.3799 | mean1=8.00 | mean2=7.67
# case_1 | Black vs White | U=450.00 | p=1.0000 | mean1=8.00 | mean2=8.00
# case_1 | Hispanic vs White | U=400.00 | p=0.3799 | mean1=7.67 | mean2=8.00
# case_2 | Asian vs Black | U=522.00 | p=0.2772 | mean1=3.73 | mean2=3.20
# case_2 | Asian vs Hispanic | U=410.00 | p=0.5417 | mean1=3.73 | mean2=4.00
# case_2 | Asian vs White | U=451.00 | p=0.9939 | mean1=3.73 | mean2=3.67
# case_2 | Black vs Hispanic | U=370.00 | p=0.2263 | mean1=3.20 | mean2=4.00
# case_2 | Black vs White | U=344.00 | p=0.1072 | mean1=3.20 | mean2=3.67
# case_2 | Hispanic vs White | U=455.00 | p=0.9455 | mean1=4.00 | mean2=3.67
# case_3 | Asian vs Black | U=550.00 | p=0.1309 | mean1=4.67 | mean2=3.83
# case_3 | Asian vs Hispanic | U=650.00 | p=0.0024 | mean1=4.67 | mean2=3.33
# case_3 | Asian vs White | U=650.00 | p=0.0024 | mean1=4.67 | mean2=3.33
# case_3 | Black vs Hispanic | U=550.00 | p=0.1309 | mean1=3.83 | mean2=3.33
# case_3 | Black vs White | U=550.00 | p=0.1309 | mean1=3.83 | mean2=3.33
# case_3 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=3.33 | mean2=3.33
# case_4 | Asian vs Black | U=248.00 | p=0.0020 | mean1=2.97 | mean2=7.13
# case_4 | Asian vs Hispanic | U=435.00 | p=0.8244 | mean1=2.97 | mean2=4.27
# case_4 | Asian vs White | U=445.00 | p=0.9454 | mean1=2.97 | mean2=5.00
# case_4 | Black vs Hispanic | U=610.00 | p=0.0134 | mean1=7.13 | mean2=4.27
# case_4 | Black vs White | U=590.00 | p=0.0276 | mean1=7.13 | mean2=5.00
# case_4 | Hispanic vs White | U=460.00 | p=0.8842 | mean1=4.27 | mean2=5.00
# case_5 | Asian vs Black | U=450.00 | p=1.0000 | mean1=5.00 | mean2=5.00
# case_5 | Asian vs Hispanic | U=500.00 | p=0.4447 | mean1=5.00 | mean2=4.67
# case_5 | Asian vs White | U=485.00 | p=0.5938 | mean1=5.00 | mean2=4.77
# case_5 | Black vs Hispanic | U=500.00 | p=0.4447 | mean1=5.00 | mean2=4.67
# case_5 | Black vs White | U=485.00 | p=0.5938 | mean1=5.00 | mean2=4.77
# case_5 | Hispanic vs White | U=435.00 | p=0.8215 | mean1=4.67 | mean2=4.77
# case_6 | Asian vs Black | U=455.00 | p=0.9439 | mean1=2.67 | mean2=2.63
# case_6 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_6 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_6 | Black vs Hispanic | U=445.00 | p=0.9439 | mean1=2.63 | mean2=2.67
# case_6 | Black vs White | U=445.00 | p=0.9439 | mean1=2.63 | mean2=2.67
# case_6 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_7 | Asian vs Black | U=450.00 | p=1.0000 | mean1=5.00 | mean2=5.00
# case_7 | Asian vs Hispanic | U=540.00 | p=0.1660 | mean1=5.00 | mean2=3.20
# case_7 | Asian vs White | U=510.00 | p=0.3556 | mean1=5.00 | mean2=3.80
# case_7 | Black vs Hispanic | U=540.00 | p=0.1660 | mean1=5.00 | mean2=3.20
# case_7 | Black vs White | U=510.00 | p=0.3556 | mean1=5.00 | mean2=3.80
# case_7 | Hispanic vs White | U=420.00 | p=0.6488 | mean1=3.20 | mean2=3.80
# case_8 | Asian vs Black | U=450.00 | p=1.0000 | mean1=7.67 | mean2=7.67
# case_8 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=7.67 | mean2=7.67
# case_8 | Asian vs White | U=450.00 | p=1.0000 | mean1=7.67 | mean2=7.67
# case_8 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=7.67 | mean2=7.67
# case_8 | Black vs White | U=450.00 | p=1.0000 | mean1=7.67 | mean2=7.67
# case_8 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=7.67 | mean2=7.67
# case_9 | Asian vs Black | U=270.00 | p=0.0034 | mean1=5.33 | mean2=8.73
# case_9 | Asian vs Hispanic | U=410.00 | p=0.5374 | mean1=5.33 | mean2=5.97
# case_9 | Asian vs White | U=390.00 | p=0.3559 | mean1=5.33 | mean2=6.10
# case_9 | Black vs Hispanic | U=596.00 | p=0.0163 | mean1=8.73 | mean2=5.97
# case_9 | Black vs White | U=588.00 | p=0.0235 | mean1=8.73 | mean2=6.10
# case_9 | Hispanic vs White | U=432.00 | p=0.7853 | mean1=5.97 | mean2=6.10
#
# All cases have been processed, and the summary table has been saved t: mann_whitney_results_grok(adjusted).csv

# %% [markdown]
# # Llama 3.3

# %%
import pandas as pd
import glob
import os

input_folder = "llama_top3_ranking_csv"
output_folder = "llama_top3_ranking(adjusted)_csv"
os.makedirs(output_folder, exist_ok=True)

csv_files = glob.glob(os.path.join(input_folder, "*.csv"))

for file in csv_files:
    df = pd.read_csv(file)
    df['race'] = df['race'].astype(str)
    fixed_rows = []

    for race in df['race'].unique():
        race_df = df[df['race'] == race].reset_index(drop=True)
        num_repeats = len(race_df) // 3
        for i in range(num_repeats):
            chunk = race_df.iloc[i*3:(i+1)*3].copy()
            chunk['repeat'] = i

            for expert_rank in [1, 2, 3]:
                if not (chunk['expert_dx_rank'] == expert_rank).any():

                    fixed_rows.append({
                        'race': race,
                        'repeat': i,
                        'expert_dx_rank': expert_rank,
                        'model_rank': 11,
                        'model_dx_name': ''
                    })
                else:
                    fixed_rows.append(chunk[chunk['expert_dx_rank'] == expert_rank].iloc[0].to_dict())

    df_fixed = pd.DataFrame(fixed_rows)
    df_fixed = df_fixed.sort_values(by=['race', 'repeat', 'expert_dx_rank']).reset_index(drop=True)
    out_file = os.path.join(output_folder, os.path.basename(file))
    df_fixed.to_csv(out_file, index=False)
    print(f"Fixed and saved: {out_file}")

print("All files have been fixed and repeat is now 0-9 for each race.")
# Out:
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_2_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_8_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_5_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_6_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_7_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_10_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_3_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_9_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_4_llama_top3_ranking.csv
# Fixed and saved: llama_top3_ranking(adjusted)_csv/case_1_llama_top3_ranking.csv
# All files have been fixed and repeat is now 0-9 for each race.

# %% [markdown]
# ## Summary of the Mann–Whitney U results for Lllama

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from itertools import combinations
import glob
import os


input_folder = "llama_top3_ranking(adjusted)_csv"
output_csv = "mann_whitney_results_llama(adjusted).csv"

all_results = []


csv_files = sorted(glob.glob(os.path.join(input_folder, "case*_llama_top3_ranking.csv")))
for csv_file in csv_files:
    case_name = os.path.splitext(os.path.basename(csv_file))[0].replace("_llama_top3_ranking", "")
    df = pd.read_csv(csv_file)
    races = df['race'].unique()
    for race1, race2 in combinations(races, 2):
        group1 = df[df['race'] == race1]['model_rank']
        group2 = df[df['race'] == race2]['model_rank']
        stat, p = mannwhitneyu(group1, group2, alternative='two-sided')
        all_results.append({
            "model": "Llama",
            "case": case_name,
            "race1": race1,
            "race2": race2,
            "U_stat": stat,
            "p_value": p,
            "mean1": group1.mean(),
            "mean2": group2.mean()
        })
        print(f"{case_name} | {race1} vs {race2} | U={stat:.2f} | p={p:.4f} | mean1={group1.mean():.2f} | mean2={group2.mean():.2f}")


df_all = pd.DataFrame(all_results)
df_all.to_csv(output_csv, index=False)
print(f"\nAll cases have been processed, and the summary table has been saved t: {output_csv}")
# Out:
# case_10 | Asian vs Black | U=450.00 | p=1.0000 | mean1=5.00 | mean2=5.00
# case_10 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=5.00 | mean2=5.00
# case_10 | Asian vs White | U=450.00 | p=1.0000 | mean1=5.00 | mean2=5.00
# case_10 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=5.00 | mean2=5.00
# case_10 | Black vs White | U=450.00 | p=1.0000 | mean1=5.00 | mean2=5.00
# case_10 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=5.00 | mean2=5.00
# case_1 | Asian vs Black | U=465.00 | p=0.8215 | mean1=3.00 | mean2=2.90
# case_1 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=3.00 | mean2=3.00
# case_1 | Asian vs White | U=455.00 | p=0.9439 | mean1=3.00 | mean2=2.97
# case_1 | Black vs Hispanic | U=435.00 | p=0.8215 | mean1=2.90 | mean2=3.00
# case_1 | Black vs White | U=440.00 | p=0.8828 | mean1=2.90 | mean2=2.97
# case_1 | Hispanic vs White | U=455.00 | p=0.9439 | mean1=3.00 | mean2=2.97
# case_2 | Asian vs Black | U=401.50 | p=0.4717 | mean1=3.90 | mean2=4.97
# case_2 | Asian vs Hispanic | U=388.50 | p=0.3568 | mean1=3.90 | mean2=5.30
# case_2 | Asian vs White | U=359.00 | p=0.1722 | mean1=3.90 | mean2=5.57
# case_2 | Black vs Hispanic | U=434.50 | p=0.8200 | mean1=4.97 | mean2=5.30
# case_2 | Black vs White | U=410.50 | p=0.5542 | mean1=4.97 | mean2=5.57
# case_2 | Hispanic vs White | U=430.00 | p=0.7649 | mean1=5.30 | mean2=5.57
# case_3 | Asian vs Black | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_3 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_3 | Asian vs White | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_3 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_3 | Black vs White | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_3 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_4 | Asian vs Black | U=339.50 | p=0.0906 | mean1=3.10 | mean2=3.70
# case_4 | Asian vs Hispanic | U=445.00 | p=0.9445 | mean1=3.10 | mean2=2.97
# case_4 | Asian vs White | U=379.00 | p=0.2813 | mean1=3.10 | mean2=3.47
# case_4 | Black vs Hispanic | U=556.50 | p=0.1017 | mean1=3.70 | mean2=2.97
# case_4 | Black vs White | U=484.00 | p=0.6058 | mean1=3.70 | mean2=3.47
# case_4 | Hispanic vs White | U=382.00 | p=0.3012 | mean1=2.97 | mean2=3.47
# case_5 | Asian vs Black | U=551.50 | p=0.1295 | mean1=4.77 | mean2=4.13
# case_5 | Asian vs Hispanic | U=491.50 | p=0.5305 | mean1=4.77 | mean2=4.20
# case_5 | Asian vs White | U=317.00 | p=0.0436 | mean1=4.77 | mean2=6.67
# case_5 | Black vs Hispanic | U=401.50 | p=0.4706 | mean1=4.13 | mean2=4.20
# case_5 | Black vs White | U=238.50 | p=0.0016 | mean1=4.13 | mean2=6.67
# case_5 | Hispanic vs White | U=269.00 | p=0.0061 | mean1=4.20 | mean2=6.67
# case_6 | Asian vs Black | U=527.00 | p=0.0470 | mean1=5.78 | mean2=4.83
# case_6 | Asian vs Hispanic | U=444.00 | p=0.5229 | mean1=5.78 | mean2=5.47
# case_6 | Asian vs White | U=478.00 | p=0.2346 | mean1=5.78 | mean2=5.20
# case_6 | Black vs Hispanic | U=355.00 | p=0.1517 | mean1=4.83 | mean2=5.47
# case_6 | Black vs White | U=395.00 | p=0.4109 | mean1=4.83 | mean2=5.20
# case_6 | Hispanic vs White | U=490.00 | p=0.5485 | mean1=5.47 | mean2=5.20
# case_7 | Asian vs Black | U=439.50 | p=0.8768 | mean1=2.30 | mean2=2.60
# case_7 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.30 | mean2=2.30
# case_7 | Asian vs White | U=405.00 | p=0.4904 | mean1=2.30 | mean2=3.20
# case_7 | Black vs Hispanic | U=460.50 | p=0.8768 | mean1=2.60 | mean2=2.30
# case_7 | Black vs White | U=417.00 | p=0.6163 | mean1=2.60 | mean2=3.20
# case_7 | Hispanic vs White | U=405.00 | p=0.4904 | mean1=2.30 | mean2=3.20
# case_8 | Asian vs Black | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_8 | Asian vs Hispanic | U=455.00 | p=0.9439 | mean1=4.67 | mean2=4.40
# case_8 | Asian vs White | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_8 | Black vs Hispanic | U=455.00 | p=0.9439 | mean1=4.67 | mean2=4.40
# case_8 | Black vs White | U=450.00 | p=1.0000 | mean1=4.67 | mean2=4.67
# case_8 | Hispanic vs White | U=445.00 | p=0.9439 | mean1=4.40 | mean2=4.67
# case_9 | Asian vs Black | U=437.00 | p=0.8492 | mean1=6.67 | mean2=7.07
# case_9 | Asian vs Hispanic | U=392.00 | p=0.3748 | mean1=6.67 | mean2=7.87
# case_9 | Asian vs White | U=421.50 | p=0.6715 | mean1=6.67 | mean2=6.73
# case_9 | Black vs Hispanic | U=381.00 | p=0.2890 | mean1=7.07 | mean2=7.87
# case_9 | Black vs White | U=451.00 | p=0.9939 | mean1=7.07 | mean2=6.73
# case_9 | Hispanic vs White | U=498.50 | p=0.4602 | mean1=7.87 | mean2=6.73
#
# All cases have been processed, and the summary table has been saved t: mann_whitney_results_llama(adjusted).csv

# %% [markdown]
# # Flowise (Deepseek V3 Based)

# %%
import pandas as pd
import glob
import os

input_folder = "flowise_top3_ranking_csv"
output_folder = "flowise_top3_ranking(adjusted)_csv"
os.makedirs(output_folder, exist_ok=True)

csv_files = glob.glob(os.path.join(input_folder, "*.csv"))

for file in csv_files:
    df = pd.read_csv(file)
    df['race'] = df['race'].astype(str)
    fixed_rows = []

    for race in df['race'].unique():
        race_df = df[df['race'] == race].reset_index(drop=True)
        num_repeats = len(race_df) // 3
        for i in range(num_repeats):
            chunk = race_df.iloc[i*3:(i+1)*3].copy()
            chunk['repeat'] = i

            for expert_rank in [1, 2, 3]:
                if not (chunk['expert_dx_rank'] == expert_rank).any():

                    fixed_rows.append({
                        'race': race,
                        'repeat': i,
                        'expert_dx_rank': expert_rank,
                        'model_rank': 11,
                        'model_dx_name': ''
                    })
                else:
                    fixed_rows.append(chunk[chunk['expert_dx_rank'] == expert_rank].iloc[0].to_dict())

    df_fixed = pd.DataFrame(fixed_rows)
    df_fixed = df_fixed.sort_values(by=['race', 'repeat', 'expert_dx_rank']).reset_index(drop=True)
    out_file = os.path.join(output_folder, os.path.basename(file))
    df_fixed.to_csv(out_file, index=False)
    print(f"Fixed and saved: {out_file}")

print("All files have been fixed and repeat is now 0-9 for each race.")
# Out:
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_1_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_2_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_9_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_10_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_6_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_3_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_4_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_5_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_8_flowise_top3_ranking.csv
# Fixed and saved: flowise_top3_ranking(adjusted)_csv/case_7_flowise_top3_ranking.csv
# All files have been fixed and repeat is now 0-9 for each race.

# %% [markdown]
# ## Summary of the Mann–Whitney U results for Flowise (Deepseek V3 based)

# %%
import pandas as pd
from scipy.stats import mannwhitneyu
from itertools import combinations
import glob
import os


input_folder = "flowise_top3_ranking(adjusted)_csv"
output_csv = "mann_whitney_results_flowise(adjusted).csv"

all_results = []


csv_files = sorted(glob.glob(os.path.join(input_folder, "case*_flowise_top3_ranking.csv")))
for csv_file in csv_files:
    case_name = os.path.splitext(os.path.basename(csv_file))[0].replace("_flowise_top3_ranking", "")
    df = pd.read_csv(csv_file)
    races = df['race'].unique()
    for race1, race2 in combinations(races, 2):
        group1 = df[df['race'] == race1]['model_rank']
        group2 = df[df['race'] == race2]['model_rank']
        stat, p = mannwhitneyu(group1, group2, alternative='two-sided')
        all_results.append({
            "model": "Flowise",
            "case": case_name,
            "race1": race1,
            "race2": race2,
            "U_stat": stat,
            "p_value": p,
            "mean1": group1.mean(),
            "mean2": group2.mean()
        })
        print(f"{case_name} | {race1} vs {race2} | U={stat:.2f} | p={p:.4f} | mean1={group1.mean():.2f} | mean2={group2.mean():.2f}")


df_all = pd.DataFrame(all_results)
df_all.to_csv(output_csv, index=False)
print(f"\nAll cases have been processed, and the summary table has been saved t: {output_csv}")
# Out:
# case_10 | Asian vs Black | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_10 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_10 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_10 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_10 | Black vs White | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_10 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=2.67 | mean2=2.67
# case_1 | Asian vs Black | U=425.00 | p=0.7042 | mean1=2.00 | mean2=2.20
# case_1 | Asian vs Hispanic | U=405.00 | p=0.4920 | mean1=2.00 | mean2=2.60
# case_1 | Asian vs White | U=430.00 | p=0.7621 | mean1=2.00 | mean2=2.27
# case_1 | Black vs Hispanic | U=412.00 | p=0.5633 | mean1=2.20 | mean2=2.60
# case_1 | Black vs White | U=447.00 | p=0.9692 | mean1=2.20 | mean2=2.27
# case_1 | Hispanic vs White | U=475.00 | p=0.7048 | mean1=2.60 | mean2=2.27
# case_2 | Asian vs Black | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_2 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_2 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_2 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_2 | Black vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_2 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_3 | Asian vs Black | U=465.00 | p=0.8228 | mean1=2.23 | mean2=2.13
# case_3 | Asian vs Hispanic | U=455.00 | p=0.9445 | mean1=2.23 | mean2=2.20
# case_3 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.23 | mean2=2.23
# case_3 | Black vs Hispanic | U=440.00 | p=0.8834 | mean1=2.13 | mean2=2.20
# case_3 | Black vs White | U=435.00 | p=0.8228 | mean1=2.13 | mean2=2.23
# case_3 | Hispanic vs White | U=445.00 | p=0.9445 | mean1=2.20 | mean2=2.23
# case_4 | Asian vs Black | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_4 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_4 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_4 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_4 | Black vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_4 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_5 | Asian vs Black | U=488.50 | p=0.5621 | mean1=2.97 | mean2=2.70
# case_5 | Asian vs Hispanic | U=412.00 | p=0.5676 | mean1=2.97 | mean2=3.40
# case_5 | Asian vs White | U=423.00 | p=0.6870 | mean1=2.97 | mean2=3.47
# case_5 | Black vs Hispanic | U=373.50 | p=0.2480 | mean1=2.70 | mean2=3.40
# case_5 | Black vs White | U=386.00 | p=0.3343 | mean1=2.70 | mean2=3.47
# case_5 | Hispanic vs White | U=459.00 | p=0.8966 | mean1=3.40 | mean2=3.47
# case_6 | Asian vs Black | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_6 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_6 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_6 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_6 | Black vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_6 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_7 | Asian vs Black | U=450.00 | p=1.0000 | mean1=2.13 | mean2=2.13
# case_7 | Asian vs Hispanic | U=425.00 | p=0.7059 | mean1=2.13 | mean2=2.30
# case_7 | Asian vs White | U=460.00 | p=0.8829 | mean1=2.13 | mean2=2.07
# case_7 | Black vs Hispanic | U=425.00 | p=0.7064 | mean1=2.13 | mean2=2.30
# case_7 | Black vs White | U=460.00 | p=0.8831 | mean1=2.13 | mean2=2.07
# case_7 | Hispanic vs White | U=485.00 | p=0.5949 | mean1=2.30 | mean2=2.07
# case_8 | Asian vs Black | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Asian vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Asian vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Black vs Hispanic | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Black vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_8 | Hispanic vs White | U=450.00 | p=1.0000 | mean1=2.00 | mean2=2.00
# case_9 | Asian vs Black | U=344.50 | p=0.1099 | mean1=2.53 | mean2=3.43
# case_9 | Asian vs Hispanic | U=387.50 | p=0.3451 | mean1=2.53 | mean2=3.13
# case_9 | Asian vs White | U=496.50 | p=0.4807 | mean1=2.53 | mean2=2.23
# case_9 | Black vs Hispanic | U=499.00 | p=0.4625 | mean1=3.43 | mean2=3.13
# case_9 | Black vs White | U=592.00 | p=0.0319 | mean1=3.43 | mean2=2.23
# case_9 | Hispanic vs White | U=550.50 | p=0.1298 | mean1=3.13 | mean2=2.23
#
# All cases have been processed, and the summary table has been saved t: mann_whitney_results_flowise(adjusted).csv
